# %%
#1
list = []

for i in range(5+1):
    if i == 0:
        breakpoint
    else:
        idade = int(input(f"Digite {i}º idades =>"))
        list.append(idade)

intervalo_min = 10
intervalo_max = 20
contador = len(listB)
listB = []

for i in range(len(list)):
    x = list[i]
    if intervalo_min< x  and x <intervalo_max:
        listB.append(x)


maximo = max(list)
minimo = min(list)
media = sum(list) / len(list)
list.sort()

print(f"Sua lista é {list} \nSeu máximo é {maximo} e minima é {minimo} \nSua média é {media}")
print(f"Os valores do seu intervalo é {intervalo_min} e {intervalo_max}, {contador} numero(s) no intervalo\nSeus numeros são {listB}")
# Out:
# Sua lista é [13, 13, 14, 16, 25]
# Seu máximo é 25 e minima é 13
# Sua média é 16.2
# Os valores do seu intervalo é 10 e 20, são 4 numero(s)
# Seus numeros são [13, 14, 13, 16]

# %%
#2
# Out:
# [12, 15, 19]
